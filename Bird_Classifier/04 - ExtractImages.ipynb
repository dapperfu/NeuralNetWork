# %% [markdown]
# # Extract Images
#
# The animal images are packed into arrays which is convenient for data analysis but not very human 'readable'.
#
# This notebook will take all of the images and expand them into folders as png images.

# %%
import h5py
from PIL import Image

# %%
hdf_dataset = "merged_dataset.hdf5"
with h5py.File(hdf_dataset, "r") as fid:
    animal_pictures = fid["animal_pictures"].value
    animal_classification = fid["animal_classification"].value

# %%
# Out:
# Animal #0
# Classification #0
# [ 0.  1.]
# Animal #1
# Classification #1
# [ 0.  1.]
# Animal #2
# Classification #2
# [ 0.  1.]
# Animal #3
# Classification #3
# [ 1.  0.]
# Animal #4
# Classification #4
# [ 1.  0.]
