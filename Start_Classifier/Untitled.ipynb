# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from control.matlab import *
# %matplotlib inline

# %%
K = 1
tau = 1
sys1 = tf(K, [tau, 1])

# %%
yout, T = step(sys1)
plt.plot(T, yout)

# %%
wn = 1
zeta = .1
sys2 = tf(wn ** 2, [1, 2*wn*zeta, wn ** 2])
yout, T = step(sys2)
plt.plot(T, yout)

# %%
wn = 1
for zeta in np.arange(0.1,0.9,0.05):
    sys2 = tf(wn ** 2, [1, 2*wn*zeta, wn ** 2])
    yout, T = step(sys2)
    plt.plot(T, yout)

# %%
wn = 1
for zeta in np.arange(0.1,0.5,0.1):
    sys2 = tf(wn ** 2, [1, 2*wn*zeta, wn ** 2])
    yout, T = step(sys2)
    plt.plot(T, yout)

# %%
wn = 1
for wn in np.arange(1.0,5.0,1.0):
    zeta = 0.1
    #for zeta in np.arange(0.1,0.5,0.1):
    sys2 = tf(wn ** 2, [1, 2*wn*zeta, wn ** 2])
    yout, T = step(sys2)
    plt.plot(T, yout)
